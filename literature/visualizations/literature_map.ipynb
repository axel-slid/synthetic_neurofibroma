# %% [markdown]
# # NF1 Neurofibroma Literature Map
#
# This notebook is generated by `literature/scripts/build_literature_assets.py`. The Plotly 3D scatter is interactive in Jupyter: rotate, pan, zoom, and hover points.

# %%
# Out:
# year     category_label  evidence_type                                                                                               title
# 2015 Genetics/signaling         review        A RASopathy gene commonly mutated in cancer: the neurofibromatosis type 1 tumour suppressor.
# 2016 Genetics/signaling         review                     Neurofibromatosis type 1: Fundamental insights into cell signalling and cancer.
# 2002     Cell of origin mouse genetics                            Neurofibromas in NF1: Schwann cell origin and role of tumor environment.
# 2008   Microenvironment mouse genetics Nf1-dependent tumors require a microenvironment containing Nf1+/-- and c-kit-dependent bone marrow.
# 2009     Cell of origin mouse genetics           Cell of origin and microenvironment contribution for NF1-associated dermal neurofibromas.

# %%
# Out:
# Interactive Plotly 3D literature map
